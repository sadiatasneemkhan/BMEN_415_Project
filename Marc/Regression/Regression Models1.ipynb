# %% [markdown]
# Predicting Tumour Size with Regression

# %%
# Libraries 
import numpy as np 
import sklearn
import matplotlib.pyplot as plt 
import pandas as pd 
import tensorflow as tf
import seaborn as sns
from pandas import read_csv 
from keras.models import Sequential 
from keras.layers import Dense 
from keras.wrappers.scikit_learn import KerasRegressor 
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score 
from sklearn.model_selection import KFold 
from sklearn.pipeline import Pipeline 
from sklearn.model_selection import train_test_split

# %%
# Importing Dataset and extracting the independent and dependent variables 
tumour = pd.read_csv('C:/Users/marcv/Downloads/regression.csv')

#Splitting the data set
X = tumour.iloc[:, :-1].values
y = tumour.iloc[:, 9].values 
X_train, X_test, y_train, y_test, = train_test_split(X, y, test_size = 0.2, random_state = 20)

# %%
#Scaling the data 
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler()
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# Regression using Neural Networks

# %%
# Defining the model 
model = Sequential()
model.add(Dense(128, input_dim = 9, activation = 'relu'))
model.add(Dense(64, activation = 'relu'))

# Output Layer
model.add(Dense(1, activation = 'linear'))

model.compile(loss = 'mean_squared_error', optimizer = 'adam', metrics = ['mae'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 128)               1280
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dense_8 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 9,601
# Trainable params: 9,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train_scaled, y_train, validation_split = 0.2, epochs = 100)
# Out:
# Epoch 1/100
# 183/183 [==============================] - 1s 1ms/step - loss: 45.6167 - mae: 5.0720 - val_loss: 29.9462 - val_mae: 4.3290
# Epoch 2/100
# 183/183 [==============================] - 0s 800us/step - loss: 27.1267 - mae: 4.2315 - val_loss: 25.6583 - val_mae: 4.1971
# Epoch 3/100
# 183/183 [==============================] - 0s 822us/step - loss: 25.1622 - mae: 4.1034 - val_loss: 24.6390 - val_mae: 4.0264
# Epoch 4/100
# 183/183 [==============================] - 0s 1ms/step - loss: 24.5288 - mae: 4.0244 - val_loss: 24.4961 - val_mae: 3.9986
# Epoch 5/100
# 183/183 [==============================] - 0s 919us/step - loss: 24.0536 - mae: 3.9580 - val_loss: 23.8873 - val_mae: 3.9549
# Epoch 6/100
# 183/183 [==============================] - 0s 867us/step - loss: 23.7545 - mae: 3.9468 - val_loss: 24.1654 - val_mae: 3.9951
# Epoch 7/100
# 183/183 [==============================] - 0s 2ms/step - loss: 23.4386 - mae: 3.9131 - val_loss: 23.5948 - val_mae: 3.9185
# Epoch 8/100
# 183/183 [==============================] - 0s 942us/step - loss: 23.3072 - mae: 3.8917 - val_loss: 23.0534 - val_mae: 3.8553
# Epoch 9/100
# 183/183 [==============================] - 0s 1ms/step - loss: 23.0710 - mae: 3.8714 - val_loss: 23.5378 - val_mae: 3.8094
# Epoch 10/100
# 183/183 [==============================] - 0s 842us/step - loss: 22.8668 - mae: 3.8484 - val_loss: 23.3321 - val_mae: 3.8585
# Epoch 11/100
# 183/183 [==============================] - 0s 930us/step - loss: 22.6966 - mae: 3.8249 - val_loss: 22.8912 - val_mae: 3.8249
# Epoch 12/100
# 183/183 [==============================] - 0s 997us/step - loss: 22.4638 - mae: 3.8178 - val_loss: 22.6044 - val_mae: 3.7835
# Epoch 13/100
# 183/183 [==============================] - 0s 816us/step - loss: 22.2305 - mae: 3.7778 - val_loss: 22.5845 - val_mae: 3.8062
# Epoch 14/100
# 183/183 [==============================] - 0s 832us/step - loss: 22.2002 - mae: 3.7804 - val_loss: 22.9423 - val_mae: 3.8788
# Epoch 15/100
# 183/183 [==============================] - 0s 1ms/step - loss: 21.9255 - mae: 3.7579 - val_loss: 22.3024 - val_mae: 3.7669
# Epoch 16/100
# 183/183 [==============================] - 0s 838us/step - loss: 21.9534 - mae: 3.7431 - val_loss: 23.3895 - val_mae: 3.9442
# Epoch 17/100
# 183/183 [==============================] - 0s 867us/step - loss: 21.7626 - mae: 3.7455 - val_loss: 22.0059 - val_mae: 3.6888
# Epoch 18/100
# 183/183 [==============================] - 0s 943us/step - loss: 21.4715 - mae: 3.7073 - val_loss: 22.4390 - val_mae: 3.7636
# Epoch 19/100
# 183/183 [==============================] - 0s 838us/step - loss: 21.3742 - mae: 3.6886 - val_loss: 21.7195 - val_mae: 3.7362
# Epoch 20/100
# 183/183 [==============================] - 0s 858us/step - loss: 21.2673 - mae: 3.6764 - val_loss: 21.8888 - val_mae: 3.6785
# Epoch 21/100
# 183/183 [==============================] - 0s 864us/step - loss: 21.0762 - mae: 3.6467 - val_loss: 21.6400 - val_mae: 3.7065
# Epoch 22/100
# 183/183 [==============================] - 0s 1ms/step - loss: 20.8844 - mae: 3.6412 - val_loss: 21.4102 - val_mae: 3.6605
# Epoch 23/100
# 183/183 [==============================] - 0s 868us/step - loss: 20.7586 - mae: 3.6223 - val_loss: 21.2565 - val_mae: 3.6227
# Epoch 24/100
# 183/183 [==============================] - 0s 845us/step - loss: 20.6937 - mae: 3.6097 - val_loss: 21.8580 - val_mae: 3.7286
# Epoch 25/100
# 183/183 [==============================] - 0s 852us/step - loss: 20.5574 - mae: 3.6154 - val_loss: 21.9615 - val_mae: 3.6807
# Epoch 26/100
# 183/183 [==============================] - 0s 841us/step - loss: 20.4860 - mae: 3.5964 - val_loss: 21.2370 - val_mae: 3.6005
# Epoch 27/100
# 183/183 [==============================] - 0s 823us/step - loss: 20.4797 - mae: 3.5770 - val_loss: 22.7961 - val_mae: 3.8458
# Epoch 28/100
# 183/183 [==============================] - 0s 928us/step - loss: 20.2175 - mae: 3.5586 - val_loss: 21.2976 - val_mae: 3.6990
# Epoch 29/100
# 183/183 [==============================] - 0s 827us/step - loss: 20.0012 - mae: 3.5424 - val_loss: 20.8625 - val_mae: 3.5356
# Epoch 30/100
# 183/183 [==============================] - 0s 1ms/step - loss: 19.9159 - mae: 3.5232 - val_loss: 21.3000 - val_mae: 3.5408
# Epoch 31/100
# 183/183 [==============================] - 0s 880us/step - loss: 19.9331 - mae: 3.5248 - val_loss: 20.7035 - val_mae: 3.5625
# Epoch 32/100
# 183/183 [==============================] - 0s 1ms/step - loss: 19.6992 - mae: 3.4980 - val_loss: 20.6459 - val_mae: 3.6094
# Epoch 33/100
# 183/183 [==============================] - 0s 965us/step - loss: 19.6841 - mae: 3.4944 - val_loss: 21.2202 - val_mae: 3.5545
# Epoch 34/100
# 183/183 [==============================] - 0s 988us/step - loss: 19.5906 - mae: 3.4924 - val_loss: 20.5080 - val_mae: 3.5468
# Epoch 35/100
# 183/183 [==============================] - 0s 947us/step - loss: 19.5215 - mae: 3.4807 - val_loss: 20.6067 - val_mae: 3.5538
# Epoch 36/100
# 183/183 [==============================] - 0s 845us/step - loss: 19.5492 - mae: 3.4864 - val_loss: 20.7320 - val_mae: 3.6008
# Epoch 37/100
# 183/183 [==============================] - 0s 818us/step - loss: 19.3104 - mae: 3.4711 - val_loss: 20.2390 - val_mae: 3.5558
# Epoch 38/100
# 183/183 [==============================] - 0s 872us/step - loss: 19.3147 - mae: 3.4606 - val_loss: 20.4740 - val_mae: 3.4753
# Epoch 39/100
# 183/183 [==============================] - 0s 848us/step - loss: 18.9895 - mae: 3.4393 - val_loss: 20.2705 - val_mae: 3.4872
# Epoch 40/100
# 183/183 [==============================] - 0s 1ms/step - loss: 18.9062 - mae: 3.4132 - val_loss: 20.0233 - val_mae: 3.4709
# Epoch 41/100
# 183/183 [==============================] - 0s 852us/step - loss: 18.9460 - mae: 3.4312 - val_loss: 20.0679 - val_mae: 3.5103
# Epoch 42/100
# 183/183 [==============================] - 0s 838us/step - loss: 18.8166 - mae: 3.4075 - val_loss: 20.6802 - val_mae: 3.4926
# Epoch 43/100
# 183/183 [==============================] - 0s 859us/step - loss: 18.6995 - mae: 3.3895 - val_loss: 20.1147 - val_mae: 3.5068
# Epoch 44/100
# 183/183 [==============================] - 0s 812us/step - loss: 18.7752 - mae: 3.4050 - val_loss: 20.3372 - val_mae: 3.5049
# Epoch 45/100
# 183/183 [==============================] - 0s 1ms/step - loss: 18.6834 - mae: 3.3906 - val_loss: 20.6304 - val_mae: 3.4297
# Epoch 46/100
# 183/183 [==============================] - 0s 890us/step - loss: 18.4383 - mae: 3.3640 - val_loss: 20.0430 - val_mae: 3.4054
# Epoch 47/100
# 183/183 [==============================] - 0s 817us/step - loss: 18.6120 - mae: 3.3759 - val_loss: 19.7244 - val_mae: 3.4200
# Epoch 48/100
# 183/183 [==============================] - 0s 826us/step - loss: 18.4084 - mae: 3.3672 - val_loss: 20.3631 - val_mae: 3.4933
# Epoch 49/100
# 183/183 [==============================] - 0s 824us/step - loss: 18.4602 - mae: 3.3660 - val_loss: 20.0587 - val_mae: 3.4705
# Epoch 50/100
# 183/183 [==============================] - 0s 834us/step - loss: 18.3960 - mae: 3.3595 - val_loss: 19.9531 - val_mae: 3.4410
# Epoch 51/100
# 183/183 [==============================] - 0s 876us/step - loss: 18.5998 - mae: 3.3593 - val_loss: 19.9378 - val_mae: 3.4374
# Epoch 52/100
# 183/183 [==============================] - 0s 955us/step - loss: 18.2076 - mae: 3.3334 - val_loss: 20.6734 - val_mae: 3.5398
# Epoch 53/100
# 183/183 [==============================] - 0s 826us/step - loss: 18.0103 - mae: 3.3297 - val_loss: 20.2550 - val_mae: 3.4090
# Epoch 54/100
# 183/183 [==============================] - 0s 811us/step - loss: 18.2465 - mae: 3.3309 - val_loss: 19.7907 - val_mae: 3.4420
# Epoch 55/100
# 183/183 [==============================] - 0s 808us/step - loss: 17.9317 - mae: 3.3097 - val_loss: 20.1951 - val_mae: 3.5553
# Epoch 56/100
# 183/183 [==============================] - 0s 827us/step - loss: 17.8978 - mae: 3.3102 - val_loss: 19.6562 - val_mae: 3.4329
# Epoch 57/100
# 183/183 [==============================] - 0s 1ms/step - loss: 18.1749 - mae: 3.3206 - val_loss: 20.2799 - val_mae: 3.5159
# Epoch 58/100
# 183/183 [==============================] - 0s 881us/step - loss: 18.0541 - mae: 3.3123 - val_loss: 19.6690 - val_mae: 3.4451
# Epoch 59/100
# 183/183 [==============================] - 0s 1ms/step - loss: 17.7352 - mae: 3.2889 - val_loss: 19.9630 - val_mae: 3.5109
# Epoch 60/100
# 183/183 [==============================] - 0s 939us/step - loss: 17.6104 - mae: 3.2832 - val_loss: 19.7648 - val_mae: 3.3921
# Epoch 61/100
# 183/183 [==============================] - 0s 1ms/step - loss: 17.8281 - mae: 3.2709 - val_loss: 19.6837 - val_mae: 3.3787
# Epoch 62/100
# 183/183 [==============================] - 0s 1ms/step - loss: 17.4470 - mae: 3.2622 - val_loss: 20.5707 - val_mae: 3.5034
# Epoch 63/100
# 183/183 [==============================] - 0s 865us/step - loss: 17.5236 - mae: 3.2624 - val_loss: 20.0418 - val_mae: 3.3590
# Epoch 64/100
# 183/183 [==============================] - 0s 959us/step - loss: 17.3712 - mae: 3.2435 - val_loss: 19.6441 - val_mae: 3.4432
# Epoch 65/100
# 183/183 [==============================] - 0s 1ms/step - loss: 17.3692 - mae: 3.2505 - val_loss: 19.6318 - val_mae: 3.4063
# Epoch 66/100
# 183/183 [==============================] - 0s 858us/step - loss: 17.3150 - mae: 3.2486 - val_loss: 20.0643 - val_mae: 3.4184
# Epoch 67/100
# 183/183 [==============================] - 0s 967us/step - loss: 17.3604 - mae: 3.2420 - val_loss: 19.5480 - val_mae: 3.4425
# Epoch 68/100
# 183/183 [==============================] - 0s 1ms/step - loss: 17.1440 - mae: 3.2195 - val_loss: 19.1976 - val_mae: 3.3808
# Epoch 69/100
# 183/183 [==============================] - 0s 821us/step - loss: 17.1082 - mae: 3.2157 - val_loss: 20.6296 - val_mae: 3.4357
# Epoch 70/100
# 183/183 [==============================] - 0s 807us/step - loss: 17.1406 - mae: 3.2191 - val_loss: 19.1847 - val_mae: 3.3166
# Epoch 71/100
# 183/183 [==============================] - 0s 844us/step - loss: 17.1394 - mae: 3.2141 - val_loss: 20.6834 - val_mae: 3.5636
# Epoch 72/100
# 183/183 [==============================] - 0s 819us/step - loss: 17.6591 - mae: 3.2474 - val_loss: 19.3262 - val_mae: 3.3835
# Epoch 73/100
# 183/183 [==============================] - 0s 811us/step - loss: 17.1639 - mae: 3.2082 - val_loss: 19.4699 - val_mae: 3.4147
# Epoch 74/100
# 183/183 [==============================] - 0s 811us/step - loss: 17.0082 - mae: 3.1980 - val_loss: 19.1459 - val_mae: 3.3656
# Epoch 75/100
# 183/183 [==============================] - 0s 817us/step - loss: 16.7446 - mae: 3.1712 - val_loss: 20.2380 - val_mae: 3.4076
# Epoch 76/100
# 183/183 [==============================] - 0s 823us/step - loss: 16.7159 - mae: 3.1774 - val_loss: 19.0429 - val_mae: 3.3649
# Epoch 77/100
# 183/183 [==============================] - 0s 806us/step - loss: 16.8059 - mae: 3.1826 - val_loss: 19.3581 - val_mae: 3.3942
# Epoch 78/100
# 183/183 [==============================] - 0s 806us/step - loss: 16.7593 - mae: 3.1755 - val_loss: 19.7073 - val_mae: 3.3735
# Epoch 79/100
# 183/183 [==============================] - 0s 841us/step - loss: 16.6471 - mae: 3.1699 - val_loss: 19.0554 - val_mae: 3.3110
# Epoch 80/100
# 183/183 [==============================] - 0s 816us/step - loss: 16.6115 - mae: 3.1521 - val_loss: 19.4715 - val_mae: 3.4120
# Epoch 81/100
# 183/183 [==============================] - 0s 799us/step - loss: 17.2502 - mae: 3.1989 - val_loss: 19.5005 - val_mae: 3.3298
# Epoch 82/100
# 183/183 [==============================] - 0s 800us/step - loss: 16.5828 - mae: 3.1544 - val_loss: 19.0770 - val_mae: 3.3396
# Epoch 83/100
# 183/183 [==============================] - 0s 855us/step - loss: 16.5945 - mae: 3.1575 - val_loss: 18.9996 - val_mae: 3.2951
# Epoch 84/100
# 183/183 [==============================] - 0s 794us/step - loss: 16.4951 - mae: 3.1395 - val_loss: 19.2309 - val_mae: 3.3426
# Epoch 85/100
# 183/183 [==============================] - 0s 813us/step - loss: 16.4259 - mae: 3.1346 - val_loss: 19.4296 - val_mae: 3.3743
# Epoch 86/100
# 183/183 [==============================] - 0s 816us/step - loss: 16.3126 - mae: 3.1281 - val_loss: 19.4302 - val_mae: 3.2882
# Epoch 87/100
# 183/183 [==============================] - 0s 796us/step - loss: 16.2041 - mae: 3.1049 - val_loss: 19.2130 - val_mae: 3.3035
# Epoch 88/100
# 183/183 [==============================] - 0s 797us/step - loss: 16.4601 - mae: 3.1327 - val_loss: 19.6078 - val_mae: 3.4693
# Epoch 89/100
# 183/183 [==============================] - 0s 816us/step - loss: 16.3124 - mae: 3.1258 - val_loss: 19.3374 - val_mae: 3.2730
# Epoch 90/100
# 183/183 [==============================] - 0s 835us/step - loss: 16.3420 - mae: 3.1208 - val_loss: 19.0056 - val_mae: 3.2934
# Epoch 91/100
# 183/183 [==============================] - 0s 811us/step - loss: 16.2019 - mae: 3.1124 - val_loss: 19.1309 - val_mae: 3.3713
# Epoch 92/100
# 183/183 [==============================] - 0s 883us/step - loss: 16.1006 - mae: 3.1030 - val_loss: 19.0808 - val_mae: 3.2922
# Epoch 93/100
# 183/183 [==============================] - 0s 985us/step - loss: 16.1501 - mae: 3.0964 - val_loss: 19.0945 - val_mae: 3.2648
# Epoch 94/100
# 183/183 [==============================] - 0s 839us/step - loss: 16.3746 - mae: 3.1315 - val_loss: 19.9447 - val_mae: 3.3168
# Epoch 95/100
# 183/183 [==============================] - 0s 855us/step - loss: 16.0112 - mae: 3.0903 - val_loss: 19.3981 - val_mae: 3.4125
# Epoch 96/100
# 183/183 [==============================] - 0s 1ms/step - loss: 16.1323 - mae: 3.0857 - val_loss: 19.2132 - val_mae: 3.3704
# Epoch 97/100
# 183/183 [==============================] - 0s 831us/step - loss: 15.9867 - mae: 3.0874 - val_loss: 19.0159 - val_mae: 3.2978
# Epoch 98/100
# 183/183 [==============================] - 0s 844us/step - loss: 16.6303 - mae: 3.1244 - val_loss: 19.0711 - val_mae: 3.2891
# Epoch 99/100
# 183/183 [==============================] - 0s 853us/step - loss: 15.8891 - mae: 3.0765 - val_loss: 19.2362 - val_mae: 3.3631
# Epoch 100/100
# 183/183 [==============================] - 0s 859us/step - loss: 15.8210 - mae: 3.0683 - val_loss: 18.9180 - val_mae: 3.2887

# %%
#Plotting loss and validation loss
from matplotlib import pyplot as plt 
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label = 'Training loss')
plt.plot(epochs, val_loss, 'r', label = 'Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['mae']
val_acc = history.history['val_mae']
plt.plot(epochs, acc, 'y', label = 'Training MAE')
plt.plot(epochs, val_acc, 'r', label = 'Validation MAE')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Predict on test data 
predictions = model.predict(X_test_scaled)
print("Predicted values are: ", predictions)
print("Real values are: ", y_test)
# Out:
# Predicted values are:  [[8.205455 ]
#  [4.4463253]
#  [3.5373957]
#  ...
#  [7.3034916]
#  [1.0536001]
#  [1.3886383]]
# Real values are:  [ 1.95   1.715 14.726 ... 15.887  2.     2.383]

# %%
# Mean Square Error and Mean absolute Error and Plot
mse_neural, mae_neural = model.evaluate(X_test_scaled, y_test)
r2 = r2_score(y_test, predictions)
print('R2 Score:', round(r2, 2)*100, '%')
print("Mean squared error from neural net: ", mse_neural)
print("Mean absolute error from neural net: ", mae_neural)
sns.regplot(x = y_test, y = predictions)
plt.title("Neural Networks Regression Model")
plt.ylabel('Predicted')
plt.xlabel('Actual')
# Out:
# 58/58 [==============================] - 0s 605us/step - loss: 20.2044 - mae: 3.4044
# R2 Score: 47.0 %
# Mean squared error from neural net:  20.204376220703125
# Mean absolute error from neural net:  3.404419183731079
# Text(0.5, 0, 'Actual')

# %% [markdown]
# Regression using Multiple Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
regressor = LinearRegression()
regressor.fit(X_train_scaled, y_train)
y_pred_mlr = regressor.predict(X_test_scaled)
mse_mlr = mean_squared_error(y_test, y_pred_mlr)
mae_mlr = mean_absolute_error(y_test, y_pred_mlr)
r2 = r2_score(y_test, y_pred_mlr)
print('R2 Score:', round(r2, 2)*100, '%')
print("Mean squared error from multiple linear regression: ", mse_mlr)
print("Mean absolute error from multiple linear regression: ", mae_mlr )
sns.regplot(x = y_test, y = y_pred_mlr)
plt.title("Multiple Linear Regression Model")
plt.ylabel('Predicted')
plt.xlabel('Actual')
# Out:
# R2 Score: 28.000000000000004 %
# Mean squared error from multiple linear regression:  27.597227106999483
# Mean absolute error from multiple linear regression:  4.371652436946849
# Text(0.5, 0, 'Actual')

# %% [markdown]
# Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor 
model_rf = RandomForestRegressor(n_estimators = 30, random_state = 30)
model_rf.fit(X_train_scaled, y_train)
y_pred_rf = model_rf.predict(X_test_scaled)
mse_rf = mean_squared_error(y_test, y_pred_rf)
mae_rf = mean_absolute_error(y_test, y_pred_rf)
r2 = r2_score(y_test, y_pred_rf)
print('R2 Score:', round(r2, 2)*100, '%')
print("Mean squared error from Random Forest: ", mse_rf)
print("Mean absolute error from Random Forest: ", mae_rf)
sns.regplot(x = y_test, y = y_pred_rf)
plt.title("Random Forest Regression Model")
plt.ylabel('Predicted')
plt.xlabel('Actual')
# Out:
# R2 Score: 53.0 %
# Mean squared error from Random Forest:  17.846232797436397
# Mean absolute error from Random Forest:  3.039468806921676
# Text(0.5, 0, 'Actual')
